# %% [markdown]
# # VADER Sentiment

# %%
# Initial imports
from dotenv import load_dotenv
import os
from path import Path
import pandas as pd
from newsapi import NewsApiClient
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download/Update the VADER Lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shuran/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Import twitter feed from csv file

# Load the sentiment data for vaccine
trump_df = pd.read_csv('trump_tweets_Sep_2019_Sep_2020.csv', infer_datetime_format=True, parse_dates=True)
trump_df = trump_df.drop(columns="Unnamed: 0")
trump_df.head()
# Out:
#                        Time                                              Tweet
# 0  2020-09-23T14:03:08.000Z  Very important that, in order to watch that AL...
# 1  2020-09-23T13:58:47.000Z  Bay of Pigs Veterans & Hispanic Heritage Remar...
# 2  2020-09-23T13:21:10.000Z  White House News Conference today at 6:00 P.M....
# 3  2020-09-23T11:22:58.000Z  I hardly know Cindy McCain other than having p...
# 4  2020-09-22T22:53:22.000Z  A few weeks ago, I BANNED efforts to indoctrin...

# %%
# Create the sentiment scores DataFrame
sentiments = []

for index, row in trump_df.iterrows():
    try:
        text = row['Tweet']
        date = row['Time']
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
trump_df2 = pd.DataFrame(sentiments)

# # Reorder DataFrame columns
# cols = ["date", "text", "compound", "positive", "negative", "neutral"]
# gsk_df = gsk_df[cols]

trump_df2.head()
# Out:
#                                                 text  \
# 0  Very important that, in order to watch that AL...
# 1  Bay of Pigs Veterans & Hispanic Heritage Remar...
# 2  White House News Conference today at 6:00 P.M....
# 3  I hardly know Cindy McCain other than having p...
# 4  A few weeks ago, I BANNED efforts to indoctrin...
#
#                        date  compound  positive  negative  neutral
# 0  2020-09-23T14:03:08.000Z    0.4532     0.099     0.000    0.901
# 1  2020-09-23T13:58:47.000Z    0.7088     0.269     0.000    0.731
# 2  2020-09-23T13:21:10.000Z    0.8188     0.320     0.000    0.680
# 3  2020-09-23T11:22:58.000Z   -0.8816     0.064     0.235    0.701
# 4  2020-09-22T22:53:22.000Z   -0.8668     0.000     0.272    0.728

# %%
print(len(sentiments))
# Out:
# 3398

# %%
print(trump_df['Tweet'])
# Out:
# 0       Very important that, in order to watch that AL...
# 1       Bay of Pigs Veterans & Hispanic Heritage Remar...
# 2       White House News Conference today at 6:00 P.M....
# 3       I hardly know Cindy McCain other than having p...
# 4       A few weeks ago, I BANNED efforts to indoctrin...
# 5       I will be announcing my Supreme Court Nominee ...
# 6       The Democrats are only interested in BAILING O...
# 7       Nissan is rolling out it’s 2021 ROGUE from TEN...
# 8       “The Trump Century, How Our President Changed ...
# 9       The Democrats are only interested in BAILING O...
# 10      Nissan is rolling out it’s 2021 ROGUE from TEN...
# 11      “The Trump Century, How Our President Changed ...
# 12      Will be interviewed on @foxandfriends at 8:00 ...
# 13      Will be interviewed by @marklevinshow on @FoxN...
# 14                SAVE YOUR SECOND AMENDMENT, VOTE TRUMP!
# 15                              MAKE AMERICA GREAT AGAIN!
# 16                                           LAW & ORDER!
# 17      VIRGINIA, and everywhere else for that matter,...
# 18      .@GOP  We were put in this position of power a...
# 19      Today, I announced two of the LARGEST grants i...
# 20      Joe Biden delivered remarks to union members a...
# 21      Joe Biden says this is a race between Scranton...
# 22      Sleepy Joe Biden just said that he wished I cl...
# 23      Jason Lewis (@LewisForMN) will be an incredibl...
# 24      Voting starts in Virginia TODAY, and we are go...
# 25      Biden FAILED BADLY with the Swine Flu. It was ...
# 26      Mini Mike Bloomberg, after making a total fool...
# 27      Pelosi wants to take 30 Billion Dollars away f...
# 28      No one has been more wrong, more often than Bi...
# 29      On Air Force One heading to Wisconsin. Biden r...
#                               ...
# 3376    There has been no President in the history of ...
# 3377    Great new book by the brilliant Andrew McCarth...
# 3378    Secretary of State Pompeo recieved permission ...
# 3379                             PRESIDENTIAL HARASSMENT!
# 3380    They never even saw the transcript of the call...
# 3381    Pelosi, Nadler, Schiff and, of course, Maxine ...
# 3382    Such an important day at the United Nations, s...
# 3383    The Democrats are so focused on hurting the Re...
# 3384    I am currently at the United Nations represent...
# 3385    “He (President Trump) didn’t specifically ment...
# 3386    “You don’t see a direct quid pro quo in this.”...
# 3387    Will the Democrats apologize after seeing what...
# 3388    “The Democrats have been talking about Impeach...
# 3389    There has been no President in the history of ...
# 3390    Great new book by the brilliant Andrew McCarth...
# 3391    Secretary of State Pompeo recieved permission ...
# 3392                             PRESIDENTIAL HARASSMENT!
# 3393    They never even saw the transcript of the call...
# 3394    Pelosi, Nadler, Schiff and, of course, Maxine ...
# 3395    Such an important day at the United Nations, s...
# 3396    The Democrats are so focused on hurting the Re...
# 3397    I am currently at the United Nations represent...
# 3398                                                  NaN
# 3399                                                  NaN
# 3400                                                  NaN
# 3401                                                  NaN
# 3402                                                  NaN
# 3403                                                  NaN
# 3404                                                  NaN
# 3405                                                  NaN
# Name: Tweet, Length: 3406, dtype: object

# %%
# Create the sentiment scores DataFrame
gsk_sentiments = []

for article in gsk_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        gsk_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
gsk_df = pd.DataFrame(gsk_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
gsk_df = gsk_df[cols]

gsk_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-09-03  Posted \r\nDrugmakers Sanofi and GlaxoSmithKli...    0.1280
# 1  2020-09-04  Drugmaker GlaxoSmithKline has won a preliminar...    0.7964
# 2  2020-09-04  Expert reports filed in a sprawling multidistr...   -0.5859
# 3  2020-09-03  PARIS (Reuters) - French drugmaker Sanofi and ...    0.0000
# 4  2020-09-18  BRUSSELS/PARIS (Reuters) - The European Union ...    0.5423
#
#    positive  negative  neutral
# 0     0.091     0.000    0.909
# 1     0.261     0.072    0.667
# 2     0.000     0.151    0.849
# 3     0.000     0.000    1.000
# 4     0.127     0.000    0.873

# %%
# Get descriptive stats from the DataFrame
gsk_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  97.000000  97.000000  97.000000  97.000000
# mean    0.231789   0.071103   0.016113   0.912794
# std     0.356856   0.066757   0.043868   0.077354
# min    -0.817600   0.000000   0.000000   0.637000
# 25%     0.000000   0.000000   0.000000   0.864000
# 50%     0.250000   0.078000   0.000000   0.919000
# 75%     0.493900   0.124000   0.000000   1.000000
# max     0.796400   0.261000   0.223000   1.000000
